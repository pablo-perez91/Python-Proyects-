# %% [markdown]
# # Pablo Pérez
# ## Mi chuleta de markdown
# *cursiva*
#
# **Negrita**
#
# ***cursiva y en negrita***
#
# 3 pasos para ejecutar un programa en python:
# 1. poner en terminal python 3
# 2. abrir un reportorio y hacer um codigo
# 3. darle a ejecutar
#
#
# 4 comandos utiles que voy a usar:
# - print
# - for
# - else
#
# > Consejo que te ayudara a programar mejor:
# Ten paciencia y comprension lectora
#
#
# | Comando | Función |
# |  ---  | ---- |
# | Print | Imprime texto |
# | For | Bucle por Parametros |

# %%
print ("Hola mundo")

# %% [markdown]
# # Mi primer Programa en python
# Este es mi primer *Hola Mundo* en un Jupyter Notebook.
# Voy a escribir una instrucción en Python y ver el resultado.

# %%
print ("Hola mundo")

# %% [markdown]
# # Pidiendo datos al usuario
# Ahora vamos a hacer un programa que pregunte tu nombre
# y luego te salude de manera personalizada.

# %%
nombre = input ("¿Como te llamas?")
print ("Encantado de conocerte,", nombre)

# %% [markdown]
# # Suma de dos números
# Ahora vamos a escribir un programa en Python que pida dos números y muestre el resultado de sumarlos.

# %%
num1 = float(input("introduce el primer número: "))
num2 = float(input("introduce el primer número: "))

resultado = num1 + num2
print (" La suma es:", resultado)
# Out:
#  La suma es: 3.0
